# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# Link utilizzato per il dataset sito ISTAT: http://dati.istat.it/viewhtml.aspx?il=blank&vh=0000&vf=0&vcq=1100&graph=0&view-metadata=1&lang=it&QueryId=17911# (selezionare periodo 2016 - 2017)

# %%
Tabella = pd.read_csv("C:/Users/utente/Desktop/UNIMI/Spese per consumi Italia 2016 - 2017.csv")
Tabella
# Out:
#     ITTER107  Territorio    TIPO_DATO8                  Tipo dato COICOP_DICH  \
# 0         IT      Italia  FAM_VAL_PERC  famiglie (composizione %)        FOOD
# 1         IT      Italia  FAM_VAL_PERC  famiglie (composizione %)        FOOD
# 2        ITC  Nord-ovest  FAM_VAL_PERC  famiglie (composizione %)        FOOD
# 3        ITC  Nord-ovest  FAM_VAL_PERC  famiglie (composizione %)        FOOD
# 4        ITD    Nord-est  FAM_VAL_PERC  famiglie (composizione %)        FOOD
# ..       ...         ...           ...                        ...         ...
# 499      ITE      Centro  FAM_VAL_PERC  famiglie (composizione %)     TRV_HOL
# 500      ITF         Sud  FAM_VAL_PERC  famiglie (composizione %)     TRV_HOL
# 501      ITF         Sud  FAM_VAL_PERC  famiglie (composizione %)     TRV_HOL
# 502      ITG       Isole  FAM_VAL_PERC  famiglie (composizione %)     TRV_HOL
# 503      ITG       Isole  FAM_VAL_PERC  famiglie (composizione %)     TRV_HOL
#
# ...
